# %%
import sys
import pandas as pd
from sqlalchemy import create_engine

# %%
pip list
# Out:
# Package                   VersionNote: you may need to restart the kernel to use updated packages.
#
# ------------------------- ---------------
# aiofiles                  0.8.0
# aiohttp                   3.9.3
# aiosignal                 1.3.1
# alembic                   1.13.1
# anyio                     4.2.0
# appdirs                   1.4.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# async-generator           1.10
# async-lru                 2.0.4
# async-timeout             4.0.3
# atomicwrites              1.4.0
# attrs                     23.2.0
# autopep8                  1.6.0
# Babel                     2.14.0
# backcall                  0.2.0
# beautifulsoup4            4.10.0
# bleach                    6.1.0
# Brotli                    1.0.9
# certifi                   2021.10.8
# cffi                      1.15.0
# chardet                   4.0.0
# charset-normalizer        2.0.12
# ...

# %%
nyc_taxis = pd.read_csv("2_docker_sql\green_tripdata_2019-09.csv", low_memory=False)

# %%
taxi_zones = pd.read_csv("2_docker_sql\zone_lookup.csv")

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
nyc_taxis.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag
# 0       2.0  2019-09-01 00:10:53   2019-09-01 00:23:46                  N  \
# 1       2.0  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2       2.0  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3       2.0  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4       2.0  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance
# 0         1.0            65           189              5.0           2.00  \
# 1         1.0            97           225              5.0           3.20
# 2         1.0            37            61              5.0           2.99
# 3         1.0           145           112              1.0           1.73
# 4         1.0           112           198              1.0           3.42
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee
# ...

# %%
nyc_taxis.lpep_pickup_datetime = pd.to_datetime(nyc_taxis.lpep_pickup_datetime)
nyc_taxis.lpep_dropoff_datetime = pd.to_datetime(nyc_taxis.lpep_dropoff_datetime)

# %%
print(pd.io.sql.get_schema(nyc_taxis, name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" REAL,
#   "lpep_pickup_datetime" TIMESTAMP,
#   "lpep_dropoff_datetime" TIMESTAMP,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" REAL,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" REAL,
#   "trip_type" REAL,
#   "congestion_surcharge" REAL
# )

# %%
df_iter = pd.read_csv('2_docker_sql\yellow_tripdata_2021-01.csv', iterator= True, chunksize=100000)

# %%
nyc_taxis = next(df_iter)

# %%
len(nyc_taxis)
# Out:
# 100

# %%
nyc_taxis.to_sql('green_taxi_data', con=engine, if_exists='replace')
# Out:
# 63

# %%
taxi_zones.to_sql('zones', con=engine, if_exists='replace')
# Out:
# 265
